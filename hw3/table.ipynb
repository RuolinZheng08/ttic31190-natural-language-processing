# %%
import pandas as pd

# %%
pd.set_option('precision', 4)

# %%
# !mv devtest_acc.csv devtest_accu.csv

# %%
df = pd.read_csv('devtest_accu.csv')

# %%
df
# Out:
#    w         emb  devtest_accu feature freeze
# 0  0      random        0.7618     NaN    NaN
# 1  1      random        0.8258     NaN    NaN
# 2  0      random        0.7915    True    NaN
# 3  1      random        0.8474    True    NaN
# 4  0  pretrained        0.8288     NaN  False
# 5  1  pretrained        0.8812     NaN  False
# 6  1  pretrained        0.8795     NaN   True
# 7  1  pretrained        0.8926    True  False
# 8  2      random        0.8286     NaN    NaN
# 9  2  pretrained        0.8937    True  False

# %%
df = df[['emb', 'freeze', 'w', 'feature', 'devtest_accu']]

# %%
df
# Out:
#           emb freeze  w feature  devtest_accu
# 0      random    NaN  0     NaN        0.7618
# 1      random    NaN  1     NaN        0.8258
# 2      random    NaN  0    True        0.7915
# 3      random    NaN  1    True        0.8474
# 4  pretrained  False  0     NaN        0.8288
# 5  pretrained  False  1     NaN        0.8812
# 6  pretrained   True  1     NaN        0.8795
# 7  pretrained  False  1    True        0.8926
# 8      random    NaN  2     NaN        0.8286
# 9  pretrained  False  2    True        0.8937

# %%
df.loc[:, 'freeze'].fillna('-', inplace=True)
# Out:
# /scratch/ruolinzheng/conda/envs/py38/lib/python3.8/site-packages/pandas/core/series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df.loc[:, 'feature'].fillna(False, inplace=True)

# %%
df.sort_values(by=['emb', 'w', 'feature', 'freeze'], 
               ascending=[False, True, True, True],
               inplace=True)

# %%
df
# Out:
#           emb freeze  w  feature  devtest_accu
# 0      random      -  0    False        0.7618
# 2      random      -  0     True        0.7915
# 1      random      -  1    False        0.8258
# 3      random      -  1     True        0.8474
# 8      random      -  2    False        0.8286
# 4  pretrained  False  0    False        0.8288
# 5  pretrained  False  1    False        0.8812
# 6  pretrained   True  1    False        0.8795
# 7  pretrained  False  1     True        0.8926
# 9  pretrained  False  2     True        0.8937

# %%
print(df.to_latex(index=False))
# Out:
# \begin{tabular}{llrlr}
# \toprule
#         emb & freeze &  w &  feature &  devtest\_accu \\
# \midrule
#      random &      - &  0 &    False &        0.7618 \\
#      random &      - &  0 &     True &        0.7915 \\
#      random &      - &  1 &    False &        0.8258 \\
#      random &      - &  1 &     True &        0.8474 \\
#      random &      - &  2 &    False &        0.8286 \\
#  pretrained &  False &  0 &    False &        0.8288 \\
#  pretrained &  False &  1 &    False &        0.8812 \\
#  pretrained &   True &  1 &    False &        0.8795 \\
#  pretrained &  False &  1 &     True &        0.8926 \\
#  pretrained &  False &  2 &     True &        0.8937 \\
# \bottomrule
# \end{tabular}
